# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np

users=pd.read_csv("C:/Data Science/Assignments/Task 5/takehome_users.csv",encoding="ISO-8859-1")
users
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  object
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 937.6+ KB

# %%
users.isnull().sum()
# Out:
# object_id                        0
# creation_time                    0
# name                             0
# email                            0
# creation_source                  0
# last_session_creation_time    3177
# opted_in_to_mailing_list         0
# enabled_for_marketing_drip       0
# org_id                           0
# invited_by_user_id            5583
# dtype: int64

# %% [markdown]
# 1.There are null values in *'last_session_creation_time'* and *'invited_by_user_id'*
#
# Converting the *last_session_creation_time* column in the *users* dataframe to datatime format.

# %%
users['last_session_creation_time']=pd.to_datetime(users['last_session_creation_time'],unit='s')
users['creation_time']=pd.to_datetime(users['creation_time'])

users
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:30     Clausen August
# 1              2 2013-11-15 03:45:04      Poole Matthew
# 2              3 2013-03-19 23:14:52  Bottrill Mitchell
# 3              4 2013-05-21 08:09:28    Clausen Nicklas
# 4              5 2013-01-17 10:14:20          Raw Grace
# ...          ...                 ...                ...
# 11995      11996 2013-09-06 06:14:15       Meier Sophia
# 11996      11997 2013-01-10 18:28:37      Fisher Amelie
# 11997      11998 2014-04-27 12:45:16        Haynes Jake
# 11998      11999 2012-05-31 11:55:59       Faber Annett
# 11999      12000 2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
users.last_session_creation_time.dtypes
# Out:
# dtype('<M8[ns]')

# %%
users['last_session_creation_time'].min(), users['last_session_creation_time'].max()
# Out:
# (Timestamp('2012-05-31 08:20:06'), Timestamp('2014-06-06 14:58:50'))

# %%
users['creation_time'].min(), users['creation_time'].max()
# Out:
# (Timestamp('2012-05-31 00:43:27'), Timestamp('2014-05-30 23:59:19'))

# %%
user_Engagement=pd.read_csv("C:/Data Science/Assignments/Task 5/takehome_user_engagement.csv")
user_Engagement
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
user_Engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  object
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.8+ MB

# %%
user_Engagement.isnull().sum()
# Out:
# time_stamp    0
# user_id       0
# visited       0
# dtype: int64

# %% [markdown]
# There are no null values in *user_Engagement* data frame !!!

# %%
# Converting the timestamp column to DateTime format
user_Engagement["time_stamp"]=pd.to_datetime(user_Engagement["time_stamp"])
user_Engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  datetime64[ns]
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 4.8 MB

# %%
user_Engagement['user_id'].nunique()
# Out:
# 8823

# %% [markdown]
# We will create a copy of user_Engagement data frame and will apply some data manipulation methods on the copy. This is to preserve the originality of the user_Engagement dataframe.

# %% [markdown]
# *****

# %%
df1=user_Engagement.copy()
df1
# Out:
#                 time_stamp  user_id  visited
# 0      2014-04-22 03:53:30        1        1
# 1      2013-11-15 03:45:04        2        1
# 2      2013-11-29 03:45:04        2        1
# 3      2013-12-09 03:45:04        2        1
# 4      2013-12-25 03:45:04        2        1
# ...                    ...      ...      ...
# 207912 2013-09-06 06:14:15    11996        1
# 207913 2013-01-15 18:28:37    11997        1
# 207914 2014-04-27 12:45:16    11998        1
# 207915 2012-06-02 11:55:59    11999        1
# 207916 2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %% [markdown]
# We can use either groupby or pivottable to sort the columns

# %%
aPivot=pd.pivot_table(data=user_Engagement,index="user_id",values='time_stamp')
aPivot
# Out:
#                  time_stamp
# user_id
# 1       2014-04-22 03:53:30
# 2       2014-01-24 03:45:04
# 3       2013-03-19 23:14:52
# 4       2013-05-22 08:09:28
# 5       2013-01-22 10:14:20
# ...                     ...
# 11996   2013-09-06 06:14:15
# 11997   2013-01-15 18:28:37
# 11998   2014-04-27 12:45:16
# 11999   2012-06-02 11:55:59
# 12000   2014-01-26 08:57:12
#
# [8823 rows x 1 columns]

# %%
df1['visits_in_7_days']=df1.groupby('user_id',as_index=False,group_keys=False).apply(lambda x : x.rolling('7D', on="time_stamp")['user_id'].count())
df1.head()
# Out:
#            time_stamp  user_id  visited  visits_in_7_days
# 0 2014-04-22 03:53:30        1        1               1.0
# 1 2013-11-15 03:45:04        2        1               1.0
# 2 2013-11-29 03:45:04        2        1               1.0
# 3 2013-12-09 03:45:04        2        1               1.0
# 4 2013-12-25 03:45:04        2        1               1.0

# %%
df1.describe().T
# Out:
#                      count         mean          std  min     25%     50%  \
# user_id           207917.0  5913.314197  3394.941674  1.0  3087.0  5682.0
# visited           207917.0     1.000000     0.000000  1.0     1.0     1.0
# visits_in_7_days  207917.0     4.381393     2.042666  1.0     3.0     4.0
#
#                      75%      max
# user_id           8944.0  12000.0
# visited              1.0      1.0
# visits_in_7_days     6.0      7.0

# %% [markdown]
# Defining adopted user

# %%
df1[df1.visits_in_7_days>=3.0]
df1
# Out:
#                 time_stamp  user_id  visited  visits_in_7_days
# 0      2014-04-22 03:53:30        1        1               1.0
# 1      2013-11-15 03:45:04        2        1               1.0
# 2      2013-11-29 03:45:04        2        1               1.0
# 3      2013-12-09 03:45:04        2        1               1.0
# 4      2013-12-25 03:45:04        2        1               1.0
# ...                    ...      ...      ...               ...
# 207912 2013-09-06 06:14:15    11996        1               1.0
# 207913 2013-01-15 18:28:37    11997        1               1.0
# 207914 2014-04-27 12:45:16    11998        1               1.0
# 207915 2012-06-02 11:55:59    11999        1               1.0
# 207916 2014-01-26 08:57:12    12000        1               1.0
#
# [207917 rows x 4 columns]

# %%
adopted=df1.groupby('user_id')['visits_in_7_days'].max().reset_index()
adopted.head()
# Out:
#    user_id  visits_in_7_days
# 0        1               1.0
# 1        2               3.0
# 2        3               1.0
# 3        4               1.0
# 4        5               1.0

# %%
adopted['is_adopted_user']=adopted['visits_in_7_days'].apply(lambda x: 1 if x>=3 else 0)
adopted.head()
# Out:
#    user_id  visits_in_7_days  is_adopted_user
# 0        1               1.0                0
# 1        2               3.0                1
# 2        3               1.0                0
# 3        4               1.0                0
# 4        5               1.0                0

# %%
adopted.is_adopted_user.value_counts()
# Out:
# 0    7221
# 1    1602
# Name: is_adopted_user, dtype: int64

# %% [markdown]
# We are droping some columns(visits_in_7_days) as it is unneccesary in future while merging this dataframe with the users dataframe.

# %%
adopted.drop('visits_in_7_days', axis = 1, inplace=True)
adopted.head()
# Out:
#    user_id  is_adopted_user
# 0        1                0
# 1        2                1
# 2        3                0
# 3        4                0
# 4        5                0

# %% [markdown]
# Renaming the user_id column as object_id for future use

# %%
adopted.rename(columns={'user_id':'object_id'}, inplace=True)
adopted
# Out:
#       object_id  is_adopted_user
# 0             1                0
# 1             2                1
# 2             3                0
# 3             4                0
# 4             5                0
# ...         ...              ...
# 8818      11996                0
# 8819      11997                0
# 8820      11998                0
# 8821      11999                0
# 8822      12000                0
#
# [8823 rows x 2 columns]

# %%
adopted.set_index('object_id',inplace=True)
adopted
# Out:
#            is_adopted_user
# object_id
# 1                        0
# 2                        1
# 3                        0
# 4                        0
# 5                        0
# ...                    ...
# 11996                    0
# 11997                    0
# 11998                    0
# 11999                    0
# 12000                    0
#
# [8823 rows x 1 columns]

# %% [markdown]
# We will create a copy of users data frame and will apply some data manipulation methods on the copy. This is to preserve the originality of the users dataframe.

# %%
users1=users.copy()
users1
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:30     Clausen August
# 1              2 2013-11-15 03:45:04      Poole Matthew
# 2              3 2013-03-19 23:14:52  Bottrill Mitchell
# 3              4 2013-05-21 08:09:28    Clausen Nicklas
# 4              5 2013-01-17 10:14:20          Raw Grace
# ...          ...                 ...                ...
# 11995      11996 2013-09-06 06:14:15       Meier Sophia
# 11996      11997 2013-01-10 18:28:37      Fisher Amelie
# 11997      11998 2014-04-27 12:45:16        Haynes Jake
# 11998      11999 2012-05-31 11:55:59       Faber Annett
# 11999      12000 2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %% [markdown]
# We will merge the 2 dataframes into a single dataframe

# %%
new_users_df=pd.merge(users1,adopted,on='object_id',how='left')
new_users_df
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:30     Clausen August
# 1              2 2013-11-15 03:45:04      Poole Matthew
# 2              3 2013-03-19 23:14:52  Bottrill Mitchell
# 3              4 2013-05-21 08:09:28    Clausen Nicklas
# 4              5 2013-01-17 10:14:20          Raw Grace
# ...          ...                 ...                ...
# 11995      11996 2013-09-06 06:14:15       Meier Sophia
# 11996      11997 2013-01-10 18:28:37      Fisher Amelie
# 11997      11998 2014-04-27 12:45:16        Haynes Jake
# 11998      11999 2012-05-31 11:55:59       Faber Annett
# 11999      12000 2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
new_users_df.shape
# Out:
# (12000, 11)

# %%
new_users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12000 entries, 0 to 11999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  datetime64[ns]
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   datetime64[ns]
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
#  10  is_adopted_user             8823 non-null   float64
# dtypes: datetime64[ns](2), float64(2), int64(4), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# The null values in the is_adopted_user and last_session_creation_time can be filled in with 0 because we can assume that those users aren't adopted users.

# %%
new_users_df['last_session_creation_time'].fillna(0,inplace=True)
new_users_df['is_adopted_user'].fillna(0,inplace=True)

# %%
new_users_df.describe().T
# Out:
#                               count         mean          std  min      25%  \
# object_id                   12000.0  6000.500000  3464.245950  1.0  3000.75
# opted_in_to_mailing_list    12000.0     0.249500     0.432742  0.0     0.00
# enabled_for_marketing_drip  12000.0     0.149333     0.356432  0.0     0.00
# org_id                      12000.0   141.884583   124.056723  0.0    29.00
# invited_by_user_id           6417.0  5962.957145  3383.761968  3.0  3058.00
# is_adopted_user             12000.0     0.133500     0.340128  0.0     0.00
#
#                                50%      75%      max
# object_id                   6000.5  9000.25  12000.0
# opted_in_to_mailing_list       0.0     0.00      1.0
# enabled_for_marketing_drip     0.0     0.00      1.0
# org_id                       108.0   238.25    416.0
# invited_by_user_id          5954.0  8817.00  11999.0
# is_adopted_user                0.0     0.00      1.0

# %% [markdown]
# Let's see if we can extract useful information from the email variable like it's domain.

# %%
new_users_df['email_domain'] = new_users_df.email.apply(lambda x: x.split('@')[1])

# %%
new_users_df['email_domain'].value_counts()
# Out:
# gmail.com         3562
# yahoo.com         2447
# jourrapide.com    1259
# cuvox.de          1202
# gustr.com         1179
#                   ...
# lrabg.com            1
# mrytw.com            1
# ugtav.com            1
# hqhll.com            1
# iuxiw.com            1
# Name: email_domain, Length: 1184, dtype: int64

# %% [markdown]
# There are too many email domains and most of them seem fake domains so it's good to drop the column entirely. We can also drop the name and object_id columns.
#
# And for the invited_by_user_id let's convert the NULL values to 0 because the column has a Non Null value only if the creation_source was a GUEST_INVITE or a ORG_INVITE anyways.
#
# For the creation_time column let's add a column which calculates how old the account is, i.e. the number of days since the account was created.
#
# And since last_session_creation_time can be removed as well because it was in a sense used to create the adopted_user column.

# %%
new_users_df.drop(['object_id', 'name', 'email', 'email_domain'], axis = 1, inplace = True)

# %%
new_users_df.invited_by_user_id.fillna(0, inplace=True)

# %%
new_users_df['days_since_creation'] = (df1.time_stamp.max() - new_users_df.creation_time).dt.days

# %%
new_users_df.drop(['creation_time', 'last_session_creation_time'], axis = 1, inplace = True)

# %% [markdown]
# Let's OneHotEncode the creation_source column.

# %%
new_users_df = pd.get_dummies(new_users_df, columns=['creation_source'])

# %%
new_users_df.describe().T
# Out:
#                                       count         mean          std  min  \
# object_id                           12000.0  6000.500000  3464.245950  1.0
# opted_in_to_mailing_list            12000.0     0.249500     0.432742  0.0
# enabled_for_marketing_drip          12000.0     0.149333     0.356432  0.0
# org_id                              12000.0   141.884583   124.056723  0.0
# invited_by_user_id                   6417.0  5962.957145  3383.761968  3.0
# is_adopted_user                     12000.0     0.133500     0.340128  0.0
# creation_source_GUEST_INVITE        12000.0     0.180250     0.384412  0.0
# creation_source_ORG_INVITE          12000.0     0.354500     0.478381  0.0
# creation_source_PERSONAL_PROJECTS   12000.0     0.175917     0.380765  0.0
# creation_source_SIGNUP              12000.0     0.173917     0.379054  0.0
# creation_source_SIGNUP_GOOGLE_AUTH  12000.0     0.115417     0.319537  0.0
#
# ...

# %%
new_users_df.corr()['is_adopted_user']
# Out:
# C:\Users\srihr\AppData\Local\Temp\ipykernel_1104\2955584305.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_users_df.corr()['is_adopted_user']
# object_id                             0.005750
# opted_in_to_mailing_list              0.008097
# enabled_for_marketing_drip            0.004653
# org_id                                0.064523
# invited_by_user_id                    0.000675
# is_adopted_user                       1.000000
# creation_source_GUEST_INVITE          0.045408
# creation_source_ORG_INVITE           -0.007636
# creation_source_PERSONAL_PROJECTS    -0.075817
# creation_source_SIGNUP                0.009299
# creation_source_SIGNUP_GOOGLE_AUTH    0.036119
# Name: is_adopted_user, dtype: float64

# %%
for x in ['opted_in_to_mailing_list', 'enabled_for_marketing_drip', 'creation_source_GUEST_INVITE',
           'creation_source_ORG_INVITE', 'creation_source_PERSONAL_PROJECTS', 'creation_source_SIGNUP',
           'creation_source_SIGNUP_GOOGLE_AUTH']:
    g = sns.FacetGrid(new_users_df, hue = "is_adopted_user", height=3, aspect=1.5,)
    g.map(plt.hist, x, alpha=1, bins = 15)
    g.add_legend()

# %%
g = sns.FacetGrid(new_users_df, hue = "is_adopted_user", height=4, aspect=2,)
_ = g.map(plt.hist, 'days_since_creation', alpha=1, bins = 15)
_ = g.add_legend()

# %% [markdown]
# ****
